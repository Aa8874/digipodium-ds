# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(titanic['survived'].unique())
print(titanic['embarked'].unique())
# Out:
# [0 1]
# ['S' 'C' 'Q' nan]

# %% [markdown]
# # categorical graphs
#
#   -columns that have txt are generally categorical
#   -the first step is  to count the no. of unique values in column
#   -then plot the count of each category
#   -following charts a goods way to visualiz data
#
#    -bar chart
#    -pie chart
#    -line chart
#    -donut chart
#    -area chart

# %%
titanic['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
survival_count = titanic['alive'].value_counts()
print(survival_count)
survival_count.plot(kind = 'pie', autopct = '%.1f%%', title = 'survival rate')
# Out:
# alive
# no     549
# yes    342
# Name: count, dtype: int64
# <Axes: title={'center': 'survival rate'}, ylabel='count'>

# %%
survival_count.plot(
    kind = 'pie' ,
    autopct = '%.1f%%',
    title = 'survival rate',
    labels = ['survived' , 'not survived'],
    colors = ['#66b3ff' , '#ff9999'],
    labeldistance = 1.1,
    wedgeprops = {
        'width' : 0.3, # donut width
    }
)
# Out:
# <Axes: title={'center': 'survival rate'}, ylabel='count'>

# %%
survival_count.plot(
    kind = 'pie' ,
    autopct = '%.1f%%',
    title = 'no. of ppl',
    labels = ['3' , '1' , '2'],
    colors = ['#66b3ff' , '#ff9999'],
    labeldistance = 1.1,
    wedgeprops = {
        'width' : 0.5, # donut width
    }
)
# Out:
# <Axes: title={'center': 'no. of ppl'}, ylabel='count'>

# %% [markdown]
# seaborn

# %%
sns.countplot(data = titanic , x = 'alive' , hue = 'sex')
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
sns.countplot(data = titanic , x = 'alive' , hue = 'embark_town')
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
sns.jointplot(data = titanic , x = 'fare' , y = 'age')

# %%
sns.jointplot(data = titanic , x = 'fare' , y = 'age' , kind = 'scatter' , color = 'g' , hue ='survived')

# %%
sns.catplot(data = titanic , x = 'fare' , y = 'age')
# Out:
# c:\Users\aamir\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
